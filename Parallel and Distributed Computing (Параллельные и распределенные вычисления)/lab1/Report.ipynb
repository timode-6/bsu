# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(20,10))

plt.subplot(121)
plt.title('N = 500, inner dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [1, 2, 5, 10, 20, 50, 100, 500]
point_multiple = [0.0557497, 0.0551746, 0.0574909, 0.0551981, 0.0557893, 0.0557257, 0.0560652, 0.0539604]
point_multiple_parallel = [0.0342948, 0.0450309, 0.0507618, 0.0451746, 0.0451865, 0.0451767, 0.0453269, 0.0467254]
block_multiple = [0.342897, 0.10456, 0.0645251, 0.0602588, 0.0447949, 0.0414666, 0.049754, 0.050009]
block_multiple_parallel = [0.139715, 0.0572506, 0.0283784, 0.0215793, 0.0202267, 0.0244716, 0.0205729, 0.0501693]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()

plt.subplot(122)
plt.title('N = 500, outer dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [1, 2, 5, 10, 20, 50, 100, 500]
point_multiple = [0.0579608, 0.0630606, 0.0742943, 0.0503912, 0.050782, 0.0506806, 0.0505636, 0.0506385]
point_multiple_parallel = [0.0244416, 0.030257, 0.0303683, 0.0306288, 0.0307544, 0.0306183, 0.0307068, 0.03072]
block_multiple = [0.348651, 0.106037, 0.073013, 0.057226, 0.0463225, 0.0424133, 0.0540888, 0.0548609]
block_multiple_parallel = [0.138697, 0.0539201, 0.030827, 0.025512, 0.0219762, 0.0254556, 0.0234347, 0.0533379]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

plt.subplot(121)
plt.title('N = 1500, inner dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [1, 2, 5, 10, 15, 20, 30, 50, 100, 500]
point_multiple = [1.49352, 1.57944, 1.73364, 1.64508, 1.67321, 1.66467, 1.64562, 1.65798, 1.62499, 1.73596]
point_multiple_parallel = [1.53732, 1.47882, 1.04059, 1.04095, 1.04104, 1.57507, 1.56967, 1.50257, 1.47644, 1.48496]
block_multiple = [9.25153, 2.76629, 1.70303, 1.61157, 1.54702, 1.19655, 1.16389, 1.09119, 1.31851, 1.30329]
block_multiple_parallel = [3.67704, 1.3129, 0.726432, 0.534226, 0.547687, 0.546765, 0.558028, 0.579332, 0.655514, 0.692784]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()

plt.subplot(122)
plt.title('N = 1500, outer dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [1, 2, 5, 10, 15, 20, 30, 50, 100, 500]
point_multiple = [1.52216, 1.67046, 1.60933, 1.64405, 1.63421, 1.59532, 1.63654, 1.64103, 1.58005, 1.60619]
point_multiple_parallel = [0.661318, 0.778075, 0.736471, 0.77721, 0.772498, 0.750559, 0.753852, 0.738097, 0.64271, 0.705552]
block_multiple = [9.7114, 2.86844, 1.92988, 1.55056, 1.43044, 1.22563, 1.22782, 1.11083, 1.42487, 1.33057]
block_multiple_parallel = [3.07021, 1.20231, 0.810097, 0.601915, 0.528593, 0.541658, 0.525039, 0.493301, 0.577144, 0.763597]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,10))

plt.subplot(121)
plt.title('N = 2000, inner dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [1, 2, 5, 10, 20, 50, 100, 200, 500]
point_multiple = [4.76385, 4.73738, 4.67948, 4.70346, 4.69498, 4.67766, 4.80846, 4.81991, 4.71845]
point_multiple_parallel = [3.53303, 2.44876, 3.56151, 3.55675, 3.55904, 3.55281, 3.41757, 3.54827, 3.55858]
block_multiple = [24.3699, 6.77243, 4.57762, 4.05916, 2.89755, 2.62588, 3.1272, 2.92442, 2.88527]
block_multiple_parallel = [8.78264, 3.289, 1.8151, 1.27075, 1.27483, 1.2872, 1.45842, 1.44351, 1.34088]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()

plt.subplot(122)
plt.title('N = 2000, outer dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [1, 2, 5, 10, 20, 50, 100, 200, 500]
point_multiple = [4.68411, 4.64305, 4.80952, 4.78402, 4.78907, 4.83848, 4.8106, 4.69111, 4.82248]
point_multiple_parallel = [2.15611, 2.10555, 2.15829, 2.09165, 2.06508, 2.13222, 2.15156, 2.13347, 2.14413]
block_multiple = [24.4474, 6.68712, 5.19089, 3.82714, 2.92884, 2.62052, 3.37719, 3.0825, 2.97189]
block_multiple_parallel = [7.96277, 2.85774, 1.95917, 1.4186, 1.30792, 1.14427, 1.34969, 1.23973, 1.38753]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title('N = 500, inner dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [50, 100]
point_multiple = [0.0709651, 0.0534277]
point_multiple_parallel = [0.0422598, 0.0496421]
block_multiple = [0.0693446, 0.0499351]
block_multiple_parallel = [0.0248812, 0.0211283]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title('N = 1500, inner dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [50, 60, 75, 100]
point_multiple = [3.24085, 1.9803, 1.62201, 1.6063]
point_multiple_parallel = [1.66785, 1.64283, 1.48192, 1.47623]
block_multiple = [1.09961, 1.41322, 1.4021, 1.32023]
block_multiple_parallel = [0.598871, 0.541878, 0.627355, 0.655289]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title('N = 2000, inner dopar')
plt.xlabel('r')
plt.ylabel('sec')
rs = [50, 80, 100]
point_multiple = [4.73372, 4.70211, 4.69407]
point_multiple_parallel = [3.51829, 3.53339, 3.535]
block_multiple = [2.59254, 3.06208, 3.11959]
block_multiple_parallel = [1.28195, 1.40689, 1.44562]
plt.plot(rs, point_multiple, '.-', label='point_multiple')    
plt.plot(rs, point_multiple_parallel, '.-', label='point_multiple_parallel')
plt.plot(rs, block_multiple, '.-', label='block_multiple')
plt.plot(rs, block_multiple_parallel, '.-', label='block_multiple_parallel')
plt.legend()
plt.show()
